# %%
import matplotlib.pyplot as plt

# %%
plt.plot([11,22,33,44],[23,34,45,56])

# %%
import numpy as np

# %%
x = np.array([11,22,33,44])

# %%
plt.plot(x,x,"r--",lavel="y=x")
plt.plot(x,x**2,"s",lavel="y=x^2")
plt.plot(x,x**3,"g^",lavel="y=x^3")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 plt.plot(x,x,"r--",lavel="y=x")
#       2 plt.plot(x,x**2,"s",lavel="y=x^2")
#       3 plt.plot(x,x**3,"g^",lavel="y=x^3")
#
# File ~/python/day05/data_science_01/.venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/python/day05/data_science_01/.venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data_01.csv")

# %%
plt.scatter(df["コンビニ数"],df["県民取得"])
plt.xlabel("C")
plt.xlabel("P")
# Out:
# Text(0.5, 0, 'P')
